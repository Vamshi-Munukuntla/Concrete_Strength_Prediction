# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings 
import scipy.stats as stats

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Data/Concrete_without_Outliers.csv')

# %%
df
# Out:
#       Cement  Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0      540.0           0.0      0.0  162.0               2.5
# 1      540.0           0.0      0.0  162.0               2.5
# 2      332.5         142.5      0.0  228.0               0.0
# 3      332.5         142.5      0.0  228.0               0.0
# 4      198.6         132.4      0.0  192.0               0.0
# ...      ...           ...      ...    ...               ...
# 1000   276.4         116.0     90.3  179.6               8.9
# 1001   322.2           0.0    115.6  196.0              10.4
# 1002   148.5         139.4    108.6  192.7               6.1
# 1003   159.1         186.7      0.0  175.6              11.3
# 1004   260.9         100.5     78.3  200.6               8.6
#
#       Coarse_Aggregate  Fine_Aggregate    Age  Compressive_Strength
# 0               1040.0           676.0   28.0                 79.99
# 1               1055.0           676.0   28.0                 61.89
# 2                932.0           594.0  120.0                 40.27
# 3                932.0           594.0  120.0                 41.05
# 4                978.4           825.5  120.0                 44.30
# ...                ...             ...    ...                   ...
# 1000             870.1           768.3   28.0                 44.28
# 1001             817.9           813.4   28.0                 31.18
# 1002             892.4           780.0   28.0                 23.70
# 1003             989.6           788.9   28.0                 32.77
# 1004             864.5           761.5   28.0                 32.40
#
# [1005 rows x 9 columns]
